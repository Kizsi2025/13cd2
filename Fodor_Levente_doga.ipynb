# %% [markdown]
# # Task
# Load the dataframe from the file `/content/drive/MyDrive/data.csv`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/1/ingatlanarak_hu.csv', sep=';');
X = dataset.iloc[:, :-1].values;
y = dataset.iloc[:, -1].values;

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=1/3, random_state=0
)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
print(regressor.predict([[78]]))
# Out:
# [39000000.00000001]

# %%
plt.scatter(X_train, y_train, color='red', label='Adatok')
plt.plot(X_train, regressor.predict(X_train), color='blue', label='Lineáris regresszió')
plt.title('Ingatlanár és terület (Tanító halmaz)')
plt.xlabel('Terület (m²)')
plt.ylabel('Ár (Ft)')
plt.legend()
plt.show()

# %%
plt.scatter(X_test, y_test, color='red', label='Valódi értékek')
plt.plot(X_train, regressor.predict(X_train), color='blue', label='Lineáris regresszió (tanító adatok alapján)')
plt.title('Ingatlanár és terület (Teszt halmaz)')
plt.xlabel('Terület (m²)')
plt.ylabel('Ár (Ft)')
plt.legend()
plt.show()
