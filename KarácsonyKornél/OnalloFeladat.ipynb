# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/autok2.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [['5000']
#  ['15000']
#  ['32000']
#  ['45000']
#  ['75000']
#  ['90000']
#  ['98000']
#  ['110000']
#  ['130000']
#  ['142000']
#  ['160000']
#  ['185000']
#  ['195000']
#  ['210000']
#  ['250000']]

# %%
print(y)
# Out:
# ['11500000' '7990000' '6800000' '6500000' '4900000' '4200000' '3800000'
#  '3100000' '2400000' '1950000' '1650000' '990000' '850000' '550000'
#  '350000']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
print(regressor.predict([[20]]))
# Out:
# [9054683.42107606]

# %%
x_train = x_train.astype(int)
y_train = y_train.astype(int)
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('Kilométer vs Ár (Training set)')
plt.xlabel('Kilométer (km)')
plt.ylabel('Ár (10Millió HUF)')
plt.show()
