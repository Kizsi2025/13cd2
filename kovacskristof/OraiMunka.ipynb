# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/car_price_dataset.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
print(y)
# Out:
# [[ 1]
#  [ 2]
#  [ 3]
#  [ 5]
#  [ 4]
#  [ 6]
#  [ 7]
#  [ 8]
#  [10]
#  [ 9]
#  [ 3]
#  [ 2]
#  [ 6]
#  [ 1]
#  [ 5]
#  [ 7]
#  [ 4]
#  [ 8]
#  [ 6]
#  [ 9]]
# [28000 25000 22000 18000 20000 16000 14000 13000  9000 11000 21000 24000
#  15000 35000 17000 13000 19000 12000 15000 10000]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
print(regressor.predict([[35]]))
# Out:
# [-53057.93285056]

# %%
plt.scatter(x_train, y_train, color="red")
plt.plot(x_train, regressor.predict(x_train), color="blue")
plt.title("Car prices")
plt.xlabel("Age")
plt.ylabel("Price")
plt.show()
