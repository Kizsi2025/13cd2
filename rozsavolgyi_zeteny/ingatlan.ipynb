# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ingatlan.txt')

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [[ 30.  ]
#  [ 34.74]
#  [ 39.47]
#  [ 44.21]
#  [ 48.95]
#  [ 53.68]
#  [ 58.42]
#  [ 63.16]
#  [ 67.89]
#  [ 72.63]
#  [ 77.37]
#  [ 82.11]
#  [ 86.84]
#  [ 91.58]
#  [ 96.32]
#  [101.05]
#  [105.79]
#  [110.53]
#  [115.26]
#  [120.  ]]

# %%
print(y)
# Out:
# [ 27364838  34936728  37012702  46847213  49034574  54220528  58544601
#   68058819  65256777  75317278  74626544  78938001  83006555  95216184
#   88619214  99019862 101974569 106876401 105206888 112354476]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 5, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
import matplotlib.ticker as mticker

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Ingatlan árak és négyzetméterek')
plt.xlabel('Négyzetméter (m2)')
plt.ylabel('Ár (millió Ft)')

def format_yaxis(value, tick_number):
    return f'{value / 1000000:.0f}'

plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(format_yaxis))
