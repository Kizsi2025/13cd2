# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/training_data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(X)
# Out:
# [[0.5]
#  [0.8]
#  [1. ]
#  [1.2]
#  [1.4]
#  [1.6]
#  [1.8]
#  [2. ]
#  [2.2]
#  [2.4]
#  [2.6]
#  [2.8]
#  [3. ]
#  [3.2]
#  [3.4]
#  [3.6]
#  [3.8]
#  [4. ]
#  [4.2]
#  [4.5]]

# %%
print(y)
# Out:
# [120 150 190 210 250 280 310 340 370 390 420 450 480 500 530 560 590 620
#  640 690]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
print(regressor.predict([[15]]))
# Out:
# [2185.72547537]

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Edzésidő és Elégetett kalória (Training set)')
plt.xlabel('Edzés hossza (óra)')
plt.ylabel('Elégetett kalória (kcal)')
plt.show()

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Edzésidő és Elégetett kalória (Test set)')
plt.xlabel('Edzés hossza (óra)')
plt.ylabel('Elégetett kalória (kcal)')
plt.show()
